# %% [markdown]
# # Global Status Report On Road Safety 2018 (WHO)
#
# publication: https://www.who.int/publications/i/item/9789241565684
#
# dashboard: https://extranet.who.int/roadsafety/death-on-the-roads/#vehicles/front_impact

# %%
import pandas as pd
import os
import sys
import matplotlib.pyplot as plt
import numpy as np
import geopandas as gpd
from shapely.geometry import Polygon

# %%
file = "data.xlsx"

# %%
## Alternatively, can clip to more standard European extent 
## with Central/Eastern Russia excluded
bbox = make_bbox(-36.386719,29.228890,60.292969,74.543330)
bbox_gdf = gpd.GeoDataFrame(index=[0], crs='epsg:4326', geometry = [bbox])

# %%
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
world = world.overlay(bbox_gdf, how="intersection")
world = world[world["continent"] == "Europe"][~world["name"].isin(["Russia", "Svalbard", "Iceland", "French Guiana", "Suriname"])]
europe = world["name"].values
europe
# Out:
# e:\Programming\Burgi\InfoVis-Verkeersongevallen\.conda\lib\site-packages\geopandas\geodataframe.py:1415: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   result = super().__getitem__(key)
# array(['Norway', 'France', 'Sweden', 'Belarus', 'Ukraine', 'Poland',
#        'Austria', 'Hungary', 'Moldova', 'Romania', 'Lithuania', 'Latvia',
#        'Estonia', 'Germany', 'Bulgaria', 'Greece', 'Albania', 'Croatia',
#        'Switzerland', 'Luxembourg', 'Belgium', 'Netherlands', 'Portugal',
#        'Spain', 'Ireland', 'Italy', 'Denmark', 'United Kingdom',
#        'Slovenia', 'Finland', 'Slovakia', 'Czechia', 'Bosnia and Herz.',
#        'North Macedonia', 'Serbia', 'Montenegro', 'Kosovo'], dtype=object)

# %%
# p320
data_road_users_and_death = pd.read_excel(file,sheet_name=0)
data_road_users_and_death = data_road_users_and_death[data_road_users_and_death["Country / Area"].isin(europe)].reset_index(drop=True)
data_road_users_and_death.to_csv('csv/data_road_users_and_death.csv')
data_road_users_and_death
# Out:
#                          Country / Area Population numbers for 2016a
# 0                           Afghanistan                   34 656 032  \
# 1                               Albania                    2 926 348
# 2                                Angola                   28 813 464
# 3                   Antigua and Barbuda                      100 963
# 4                             Argentina                   43 847 432
# ..                                  ...                          ...
# 170                             Vanuatu                      270 402
# 171  Venezuela (Bolivarian Republic of)                   31 568 180
# 172                            Viet Nam                   94 569 072
# 173            West Bank and Gaza Strip                    4 790 705
# 174                            Zimbabwe                   16 150 362
#
#     GNI per capita for 2016 in US dollars Reported Income level
# 0                                     580                   Low  \
# 1                                   4 250                Middle
# 2                                   3 440                Middle
# 3                                  13 400                  High
# 4                                  11 960                Middle
# ..                                    ...                   ...
# 170                                3 170g                Middle
# 171                               11 760g                Middle
# 172                                 2 050                Middle
# 173                                 3 230                Middle
# 174                                   940                   Low
#
#      number of traffic road deaths Point estimate
# 0                            1 565          5 230  \
# 1                              269            399
# 2                            2 845          6 797
# 3                                8              8
# 4                            5 530          6 119
# ..                             ...            ...
# 170                              9             43
# 171                         7 028e         10 640
# 172                          8 417         24 970
# 173                            159            252
# 174                          1 721          5 601
#
#      Estimated road traffic death rate per 100 000 population
# 0                                                 15.1         \
# 1                                                 13.6
# 2                                                 23.6
# 3                                                  7.9
# 4                                                 14.0
# ..                                                 ...
# 170                                               15.9
# 171                                               33.7
# 172                                               26.4
# 173                                                5.3
# 174                                               34.7
#
#     Drivers/Passengers of 4-wheeled vehicles
# 0                                          –  \
# 1                                       39.4
# 2                                       59.5
# 3                                       62.5
# 4                                       47.2
# ..                                       ...
# 170                                        –
# 171                                        –
# 172                                        –
# 173                                     52.2
# 174                                     26.7
#
#     Drivers / Passengers of 2- or 3- wheelers Cyclists Pedestrians
# 0                                           –        –           –  \
# 1                                        11.9      7.8        38.7
# 2                                         NaN      NaN        40.5
# 3                                           0     12.5          25
# 4                                        22.2      2.4         8.2
# ..                                        ...      ...         ...
# 170                                         –        –           –
# 171                                         –        –           –
# 172                                         –        –           –
# 173                                       2.5      1.9        32.7
# 174                                      10.2     12.2        13.7
#
#     Other or unspecified users
# 0                            –
# 1                          2.2
# 2                            0
# 3                            0
# 4                           20
# ..                         ...
# 170                          –
# 171                          –
# 172                          –
# 173                       10.7
# 174                       37.2
#
# [175 rows x 12 columns]

# %%
# p344
data_speed_laws = pd.read_excel(file,sheet_name=1)
data_speed_laws = data_speed_laws[data_speed_laws["Country / Area"].isin(europe)].reset_index(drop=True)
for col in data_speed_laws.columns[3:6]:
    data_speed_laws[col] = data_speed_laws[col].str.split("km").str[0].str.lstrip("~")
data_speed_laws = data_speed_laws.replace("—", np.nan)
data_speed_laws = data_speed_laws.replace("Yesan", "Yes")
data_speed_laws.to_csv('csv/data_speed_laws.csv')
data_speed_laws
# Out:
#     Country / Area National speed limit law Types of modifications allowed
# 0          Albania                      Yes                            Yes  \
# 1          Austria                      Yes                            Yes
# 2          Belarus                      Yes                             No
# 3          Belgium                      Yes                            Yes
# 4         Bulgaria                      Yes                             No
# 5          Croatia                      Yes                            Yes
# 6          Czechia                      Yes                            Yes
# 7          Denmark                      Yes                           Yeso
# 8          Estonia                      Yes                            Yes
# 9          Finland                      Yes                            Yes
# 10          France                      Yes                            Yes
# 11         Germany                      Yes                            Yes
# 12          Greece                      Yes                            Yes
# 13         Hungary                      Yes                            Yes
# 14         Ireland                      Yes                            Yes
# 15           Italy                      Yes                            Yes
# 16          Latvia                      Yes                             No
# 17       Lithuania                      Yes                             No
# 18      Luxembourg                      Yes                            Yes
# 19      Montenegro                      Yes                             No
# 20     Netherlands                      Yes                            Yes
# 21          Norway                      Yes                            Yes
# 22          Poland                      Yes                            Yes
# 23        Portugal                      Yes                             No
# 24         Romania                      Yes                            Yes
# 25          Serbia                      Yes                            Yes
# 26        Slovakia                      Yes                             No
# 27        Slovenia                      Yes                             No
# 28           Spain                      Yes                            Yes
# 29          Sweden                      Yes                            Yes
# 30     Switzerland                      Yes                             No
# 31         Ukraine                      Yes                            Yes
# 32  United Kingdom                      Yes                            Yes
#
#    Urban Rural Motorways  Enforcement Predominant type of enforcement
# 0    40    80       110           4.0            Manual and automated
# 1    50   100       130           NaN                       Automated
# 2    60    90       110           7.0            Manual and automated
# 3    50    90       120           7.0            Manual and automated
# 4    50    90       140           6.0                       Automated
# 5    50    90       130           7.0            Manual and automated
# 6    50    90       130           5.0                          Manual
# 7    50    80       130           NaN                       Automated
# 8    50    90        Noq          7.0                       Automated
# 9    50    80       120           8.0            Manual and automated
# 10   50    90       130           8.0                       Automated
# 11   50   100        Nos          NaN                             NaN
# 12   50    90       130           3.0                          Manual
# 13   50    90       130           6.0            Manual and automated
# 14   50   100       120          10.0                       Automated
# 15   50   110       150           8.0                       Automated
# 16   50    90         No          7.0            Manual and automated
# 17   50    90       130           7.0                       Automated
# 18   50    90       130           7.0                       Automated
# 19   50    80       130           7.0                          Manual
# 20   50    80       130           6.0            Manual and automated
# 21   50    80       100          10.0            Manual and automated
# 22   50    90       140           8.0                          Manual
# 23   50    90       120           7.0                          Manual
# 24   50    90       130           7.0                          Manual
# 25   50   100       120           6.0                          Manual
# 26   50    90       130           7.0                          Manual
# 27   50    90       130           7.0                          Manual
# 28   50    90       120           8.0            Manual and automated
# 29   50   110       120           8.0                       Automated
# 30   50    80       120           7.0                             NaN
# 31   60    90       130           3.0                             NaN
# 32   48    96       112           8.0                       Automated

# %%
data_drinking_driving = pd.read_excel(file,sheet_name=2)
data_drinking_driving = data_drinking_driving[data_drinking_driving["Country / Area"].isin(europe)].reset_index(drop=True)
data_drinking_driving = data_drinking_driving.replace("Yesa", "Yes")
data_drinking_driving = data_drinking_driving.replace("Yesv", "Yes")
data_drinking_driving = data_drinking_driving.replace("Yese", "Yes")
data_drinking_driving = data_drinking_driving.replace("Yesh", "Yes")
data_drinking_driving = data_drinking_driving.replace("Yesm", "Yes")
data_drinking_driving = data_drinking_driving.replace("Yesn", "Yes")
data_drinking_driving = data_drinking_driving.replace("Yess", "Yes")
data_drinking_driving = data_drinking_driving.replace("Yest", "Yes")
data_drinking_driving = data_drinking_driving.replace("Yesu", "Yes")
data_drinking_driving = data_drinking_driving.replace("Yesb", "Yes")
data_drinking_driving = data_drinking_driving.replace("Yesd", "Yes")
data_drinking_driving = data_drinking_driving.replace("Nob", "No")
data_drinking_driving = data_drinking_driving.replace("—", np.nan)
data_drinking_driving = data_drinking_driving.replace("–", np.nan)
for col in data_drinking_driving.columns[3:6]:
    data_drinking_driving[col] = data_drinking_driving[col].str.split("≤").str[-1].str.split("<").str[-1].str.split("*").str[0]#.astype(float)#.str.lstrip("c")
    data_drinking_driving[col] = data_drinking_driving[col].replace(np.nan, 0)
data_drinking_driving.to_csv('csv/data_drinking_driving.csv')
data_drinking_driving
# Out:
#     Country / Area National drink\ndriving law Based on BAC / BrAC
# 0          Albania                         Yes                 Yes  \
# 1          Austria                         Yes                 Yes
# 2          Belarus                         Yes                 Yes
# 3          Belgium                         Yes                 Yes
# 4         Bulgaria                         Yes                 Yes
# 5          Croatia                         Yes                 Yes
# 6          Czechia                         Yes                 Yes
# 7          Denmark                         Yes                 Yes
# 8          Estonia                         Yes                 Yes
# 9          Finland                         Yes                 Yes
# 10          France                         Yes                 Yes
# 11         Germany                         Yes                 Yes
# 12          Greece                         Yes                 Yes
# 13         Hungary                         Yes                 Yes
# 14         Ireland                         Yes                 Yes
# 15           Italy                         Yes                 Yes
# 16          Latvia                         Yes                 Yes
# 17       Lithuania                         Yes                 Yes
# 18      Luxembourg                         Yes                 Yes
# 19      Montenegro                         Yes                 Yes
# 20     Netherlands                         Yes                 Yes
# 21          Norway                         Yes                 Yes
# 22          Poland                         Yes                 Yes
# 23        Portugal                         Yes                 Yes
# 24         Romania                         Yes                 Yes
# 25          Serbia                         Yes                 Yes
# 26        Slovakia                         Yes                 Yes
# 27        Slovenia                         Yes                 Yes
# 28           Spain                         Yes                 Yes
# 29          Sweden                         Yes                 Yes
# 30     Switzerland                         Yes                 Yes
# 31         Ukraine                         Yes                 Yes
# 32  United Kingdom                         Yes                 Yes
#
#    General population Young / novice drivers
# 0                0.05                   0.05  \
# 1                0.05                   0.01
# 2                0.03                   0.03
# 3                0.05                   0.05
# 4                0.05                   0.05
# 5                0.05                      0
# 6                0.03                   0.03
# 7                0.05                   0.05
# 8                0.02                   0.02
# 9                0.05                   0.05
# 10               0.05                   0.02
# 11               0.05                      0
# 12               0.05                   0.05
# 13                  0                      0
# 14               0.05                   0.02
# 15               0.05                      0
# 16               0.05                   0.02
# 17               0.04                      0
# 18               0.05                   0.02
# 19               0.03                      0
# 20               0.05                   0.02
# 21               0.02                   0.02
# 22               0.02                   0.02
# 23               0.05                   0.02
# 24               0.08                   0.08
# 25               0.03                      0
# 26                  0                      0
# 27               0.05                      0
# 28               0.05                   0.03
# 29               0.02                   0.02
# 30               0.05                   0.01
# 31               0.02                   0.02
# 32               0.08                   0.08
#
#    Professional / commercial drivers Random breath testing carried out
# 0                               0.05                               Yes  \
# 1                               0.01                               Yes
# 2                               0.03                               Yes
# 3                               0.02                               Yes
# 4                               0.05                               Yes
# 5                                  0                               Yes
# 6                               0.03                               Yes
# 7                               0.05                               Yes
# 8                               0.02                               Yes
# 9                               0.05                               Yes
# 10                              0.05                               Yes
# 11                              0.05                               Yes
# 12                              0.05                               Yes
# 13                                 0                               Yes
# 14                              0.02                               Yes
# 15                                 0                               Yes
# 16                              0.02                               Yes
# 17                                 0                               Yes
# 18                              0.02                               Yes
# 19                              0.03                               Yes
# 20                              0.05                               Yes
# 21                              0.02                               Yes
# 22                              0.02                               Yes
# 23                              0.02                               Yes
# 24                              0.08                               Yes
# 25                                 0                               Yes
# 26                                 0                               Yes
# 27                                 0                               Yes
# 28                              0.03                               Yes
# 29                              0.02                               Yes
# 30                              0.01                               Yes
# 31                              0.02                                No
# 32                              0.08                               Yes
#
#    Testing carried out in case of fatal crash  Enforcement
# 0                         Some drivers tested          6.0  \
# 1                          All drivers tested          NaN
# 2                          All drivers tested          8.0
# 3                         Some drivers tested          6.0
# 4                          All drivers tested          5.0
# 5                         Some drivers tested          8.0
# 6                          All drivers tested          7.0
# 7                         Some drivers tested          NaN
# 8                          All drivers tested          8.0
# 9                          All drivers tested          9.0
# 10                         All drivers tested          7.0
# 11                        Some drivers tested          NaN
# 12                         All drivers tested          4.0
# 13                         All drivers tested          5.0
# 14                         All drivers tested         10.0
# 15                        Some drivers tested          7.0
# 16                         All drivers tested          7.0
# 17                         All drivers tested          8.0
# 18                         All drivers tested          6.0
# 19                         All drivers tested          7.0
# 20                                         No          6.0
# 21                        Some drivers tested         10.0
# 22                         All drivers tested         10.0
# 23                         All drivers tested          7.0
# 24                         All drivers tested          8.0
# 25                         All drivers tested          5.0
# 26                         All drivers tested          8.0
# 27                         All drivers tested          7.0
# 28                        Some drivers tested          7.0
# 29                         All drivers tested          6.0
# 30                        Some drivers tested          6.0
# 31                         All drivers tested          5.0
# 32                         All drivers tested          8.0
#
#    % road traffic deaths involving alcohol National drug driving law
# 0                                      5.2                       Yes  \
# 1                                      5.1                       Yes
# 2                           14.3 (Drivers)                       Yes
# 3                                      NaN                       Yes
# 4                                      0.9                       Yes
# 5                                     23.8                       Yes
# 6                                      9.5                       Yes
# 7                                      NaN                       Yes
# 8                                       10                       Yes
# 9                                       24                       Yes
# 10                                      29                       Yes
# 11                                       7                       Yes
# 12                                    25.3                       Yes
# 13                                     7.1                       Yes
# 14                                    38.5                       Yes
# 15                                 20 - 25                       Yes
# 16                                    10.8                       Yes
# 17                                     9.6                       Yes
# 18                                      14                       Yes
# 19                                     NaN                       Yes
# 20                                 11 - 24                       Yes
# 21                                      13                       Yes
# 22                                    12.7                       Yes
# 23                                    29.2                       Yes
# 24                                     5.6                       Yes
# 25                                      17                       Yes
# 26                                     6.1                       Yes
# 27                                      32                       Yes
# 28                  17 Males, 6.7\nFemales                       Yes
# 29                                      24                       Yes
# 30                                      13                       Yes
# 31                                     6.7                       Yes
# 32                        13 (GB), 23 (NI)                       Yes
#
#    Alcohol prohibited
# 0                  No
# 1                  No
# 2                  No
# 3                  No
# 4                  No
# 5                  No
# 6                  No
# 7                  No
# 8                  No
# 9                  No
# 10                 No
# 11                 No
# 12                 No
# 13                 No
# 14                 No
# 15                 No
# 16                 No
# 17                 No
# 18                 No
# 19                 No
# 20                 No
# 21                 No
# 22                 No
# 23                 No
# 24                 No
# 25                 No
# 26                 No
# 27                 No
# 28                 No
# 29                 No
# 30                 No
# 31                 No
# 32                 No

# %%
data_helmet_law = pd.read_excel(file,sheet_name=3)
data_helmet_law = data_helmet_law[data_helmet_law["Country / Area"].isin(europe)].reset_index(drop=True)
data_helmet_law = data_helmet_law.replace("—", np.nan)
data_helmet_law = data_helmet_law.replace("–", np.nan)
data_helmet_law.to_csv('csv/data_helmet_law.csv')
data_helmet_law
# Out:
#     Country / Area National motorcycle helmet law Applies to driver
# 0          Albania                            Yes               Yes  \
# 1          Austria                            Yes               Yes
# 2          Belarus                            Yes               Yes
# 3          Belgium                            Yes               Yes
# 4         Bulgaria                            Yes               Yes
# 5          Croatia                            Yes               Yes
# 6          Czechia                            Yes               Yes
# 7          Denmark                            Yes               Yes
# 8          Estonia                            Yes               Yes
# 9          Finland                            Yes               Yes
# 10          France                            Yes               Yes
# 11         Germany                            Yes               Yes
# 12          Greece                            Yes               Yes
# 13         Hungary                            Yes               Yes
# 14         Ireland                            Yes               Yes
# 15           Italy                            Yes               Yes
# 16          Latvia                            Yes               Yes
# 17       Lithuania                            Yes               Yes
# 18      Luxembourg                            Yes               Yes
# 19      Montenegro                            Yes               Yes
# 20     Netherlands                            Yes               Yes
# 21          Norway                            Yes               Yes
# 22          Poland                            Yes               Yes
# 23        Portugal                            Yes               Yes
# 24         Romania                            Yes               Yes
# 25          Serbia                            Yes               Yes
# 26        Slovakia                            Yes               Yes
# 27        Slovenia                            Yes               Yes
# 28           Spain                            Yes               Yes
# 29          Sweden                            Yes               Yes
# 30     Switzerland                            Yes               Yes
# 31         Ukraine                            Yes               Yes
# 32  United Kingdom                            Yes               Yes
#
#    Applies to adult\npassengers Applies to all roads Applies to all engines
# 0                           Yes                  Yes                    Yes  \
# 1                           Yes                  Yes                    Yes
# 2                           Yes                  Yes                    Yes
# 3                           Yes                  Yes                    Yes
# 4                           Yes                  Yes                    Yes
# 5                           Yes                  Yes                    Yes
# 6                           Yes                  Yes                    Yes
# 7                           Yes                  Yes                    Yes
# 8                           Yes                  Yes                    Yes
# 9                           Yes                  Yes                    Yes
# 10                          Yes                  Yes                    Yes
# 11                          Yes                  Yes                     No
# 12                          Yes                  Yes                    Yes
# 13                          Yes                  Yes                    Yes
# 14                          Yes                  Yes                    Yes
# 15                          Yes                  Yes                    Yes
# 16                          Yes                  Yes                    Yes
# 17                          Yes                  Yes                    Yes
# 18                          Yes                  Yes                    Yes
# 19                          Yes                  Yes                    Yes
# 20                          Yes                  Yes                     No
# 21                          Yes                  Yes                    Yes
# 22                          Yes                  Yes                    Yes
# 23                          Yes                  Yes                    Yes
# 24                          Yes                  Yes                    Yes
# 25                          Yes                  Yes                    Yes
# 26                          Yes                  Yes                    Yes
# 27                          Yes                  Yes                    Yes
# 28                          Yes                  Yes                    Yes
# 29                          Yes                  Yes                    Yes
# 30                          Yes                  Yes                    Yes
# 31                          Yes                  Yes                    Yes
# 32                          Yes                  Yes                    Yes
#
#    Helmet fastening required Standard referred to and / or specified
# 0                         No                                     Yes  \
# 1                         No                                     Yes
# 2                        Yes                                     Yes
# 3                         No                                     Yes
# 4                         No                                      No
# 5                        Yes                                     Yes
# 6                        Yes                                     Yes
# 7                        Yes                                     Yes
# 8                        Yes                                     Yes
# 9                         No                                      No
# 10                       Yes                                     Yes
# 11                        No                                      No
# 12                       Yes                                     Yes
# 13                       Yes                                     Yes
# 14                        No                                     Yes
# 15                       Yes                                     Yes
# 16                       Yes                                      No
# 17                       Yes                                      No
# 18                       Yes                                     Yes
# 19                       Yes                                    Yesl
# 20                       Yes                                     Yes
# 21                        No                                     Yes
# 22                        No                                     Yes
# 23                       Yes                                     Yes
# 24                        No                                      No
# 25                       Yes                                      No
# 26                       Yes                                      No
# 27                       Yes                                     Yes
# 28                        No                                     Yes
# 29                       Yes                                     Yes
# 30                        No                                     Yes
# 31                       Yes                                      No
# 32                       Yes                                     Yes
#
#    Children passengers on motorcycles Enforcement
# 0                      Not restricted            6  \
# 1             Prohibited under 12 yrs          NaN
# 2             Prohibited under 12 yrs            8
# 3          Prohibited under 3 /8 yrsa            9
# 4             Prohibited under 12 yrs            5
# 5             Prohibited under 12 yrs            9
# 6             Prohibited under 12 yrs            9
# 7     Prohibited under 5 yrs / 135 cm          NaN
# 8             Prohibited under 12 yrs            9
# 9                      Not restricted            9
# 10                     Not restricted            9
# 11                     Not restricted          NaN
# 12             Prohibited under 5 yrs            4
# 13                     Not restricted            8
# 14                     Not restricted           10
# 15             Prohibited under 5 yrs            9
# 16            Prohibited under 150 cm            7
# 17            Prohibited under 12 yrs            9
# 18            Prohibited under 12 yrs           10
# 19            Prohibited under 12 yrs            6
# 20                     Not restricted            5
# 21                     Not restricted           10
# 22                    Not restrictedn            7
# 23             Prohibited under 7 yrs            9
# 24           Prohibited under 14 yrso            7
# 25            Prohibited under 12 yrs            8
# 26            Prohibited under 12 yrs            8
# 27           Prohibited under 12 yrsq            8
# 28        Prohibited under 7 / 12 yrs            8
# 29                     Not restricted            8
# 30                     Not restricted            9
# 31   Prohibited under 12 yrs / 145 cm            3
# 32                     Not restricted            9
#
#                             Helmet wearing rate (%)
# 0                       75% Drivers, 60% Passengers
# 1                                   100% All riders
# 2                                               NaN
# 3                      99% Drivers, 100% Passengers
# 4                       80% Drivers, 30% Passengers
# 5                       95% Drivers, 95% Passengers
# 6                                               NaN
# 7                                       98% Drivers
# 8                                       98% Drivers
# 9                                  98.3% All riders
# 10                                   98% All riders
# 11                     99% Drivers, 100% Passengers
# 12                      75% Drivers, 46% Passengers
# 13  92.3% country roads, 100% Budapest % All riders
# 14                                    99.9% Drivers
# 15                                   98% All riders
# 16                                              NaN
# 17                                              NaN
# 18                                              NaN
# 19                      70% Drivers, 30% Passengers
# 20                    99.9% Drivers, 84% Passengers
# 21                      99% Drivers, 99% Passengers
# 22                     99% Drivers, 100% Passengers
# 23                  97.6% Drivers, 97.3% Passengers
# 24                                              NaN
# 25            85.7% Drivers,74.3 - 86.5% Passengers
# 26                                              NaN
# 27                                              NaN
# 28                    99% Drivers, 93.3% Passengers
# 29       97 - 99 (97 for moped drivers)% All riders
# 30                                     100% Drivers
# 31                                              NaN
# 32                                              NaN

# %%
data_seatbelt_law = pd.read_excel(file,sheet_name=4)
data_seatbelt_law = data_seatbelt_law[data_seatbelt_law["Country / Area"].isin(europe)].reset_index(drop=True)
data_seatbelt_law = data_seatbelt_law.replace("—", np.nan)
data_seatbelt_law = data_seatbelt_law.replace("–", np.nan)
data_seatbelt_law = data_seatbelt_law.replace("—", np.nan)
data_seatbelt_law.to_csv('csv/data_seatbelt_law.csv')
data_seatbelt_law
# Out:
#     Country / Area National seat\nbelt law Drivers Front seat passengers
# 0          Albania                     Yes     Yes                   Yes  \
# 1          Austria                     Yes     Yes                   Yes
# 2          Belarus                     Yes     Yes                   Yes
# 3          Belgium                     Yes     Yes                   Yes
# 4         Bulgaria                     Yes     Yes                   Yes
# 5          Croatia                     Yes     Yes                   Yes
# 6          Czechia                     Yes     Yes                   Yes
# 7          Denmark                     Yes     Yes                   Yes
# 8          Estonia                     Yes     Yes                   Yes
# 9          Finland                     Yes     Yes                   Yes
# 10          France                     Yes     Yes                   Yes
# 11         Germany                     Yes     Yes                   Yes
# 12          Greece                     Yes     Yes                   Yes
# 13         Hungary                     Yes     Yes                   Yes
# 14         Ireland                     Yes     Yes                   Yes
# 15           Italy                     Yes     Yes                   Yes
# 16          Latvia                     Yes     Yes                   Yes
# 17       Lithuania                     Yes     Yes                   Yes
# 18      Luxembourg                     Yes     Yes                   Yes
# 19      Montenegro                     Yes     Yes                   Yes
# 20     Netherlands                     Yes     Yes                   Yes
# 21          Norway                     Yes     Yes                   Yes
# 22          Poland                     Yes     Yes                   Yes
# 23        Portugal                     Yes     Yes                   Yes
# 24         Romania                     Yes     Yes                   Yes
# 25          Serbia                     Yes     Yes                   Yes
# 26        Slovakia                     Yes     Yes                   Yes
# 27        Slovenia                     Yes     Yes                   Yes
# 28           Spain                     Yes     Yes                   Yes
# 29          Sweden                     Yes     Yes                   Yes
# 30     Switzerland                     Yes     Yes                   Yes
# 31         Ukraine                     Yes     Yes                   Yes
# 32  United Kingdom                     Yes     Yes                   Yes
#
#    Rear-seat passengers  Enforcement Drivers only     Front-seat occupants
# 0                   Yes          8.0               95                   85  \
# 1                   Yes          NaN               95                   95
# 2                   Yes          8.0              NaN                  NaN
# 3                   Yes          7.0             91.5                 92.2
# 4                   Yes          5.0              NaN                  NaN
# 5                   Yes          6.0             61.1                 61.9
# 6                   Yes          8.0               95                   98
# 7                   Yes          NaN        88/89/96*                   96
# 8                   Yes          7.0             97.8                 97.3
# 9                   Yes          8.0               96                   95
# 10                  Yes          8.0              NaN                   98
# 11                  Yes          NaN               98                   98
# 12                  Yes          4.0               77                   74
# 13                  Yes          7.0             81.7                 82.8
# 14                  Yes         10.0               92                   94
# 15                  Yes          7.0              NaN                 61.9
# 16                  Yes          7.0               81                 84.7
# 17                  Yes          7.0              NaN                   97
# 18                  Yes          7.0               93                   90
# 19                  Yes          6.0               60                   40
# 20                  Yes          6.0             96.9                 96.6
# 21                  Yes         10.0     95.9 - 97.7j         95.2 - 95.7j
# 22                  Yes          8.0               95                   96
# 23                  Yes          8.0             96.4                 95.7
# 24                  Yes          7.0              NaN                  NaN
# 25                  Yes          6.0               77                 75.1
# 26                  Yes          8.0              NaN                  NaN
# 27                  Yes          9.0             90.4                 91.8
# 28                  Yes          8.0             90.3                 90.5
# 29                  Yes          6.0               98                   96
# 30                  Yes          8.0               94                   94
# 31                  Yes          3.0              NaN                  NaN
# 32                  Yes         10.0       95.3 - 98k           94.6 - 98k
#
#    Rear-seat occupants All occupants
# 0                   80            87
# 1                   93           NaN
# 2                  NaN           NaN
# 3                 85.5          91.7
# 4                  NaN            80
# 5                 13.9            58
# 6                   72           NaN
# 7                   91           NaN
# 8                 81.8            95
# 9                   85            94
# 10                  88           NaN
# 11                  99            98
# 12                  23            72
# 13                38.5            81
# 14                  74            91
# 15                15.4           NaN
# 16                  53           NaN
# 17                  30            94
# 18                  76            92
# 19                   5            35
# 20                  82          95.8
# 21                 NaN    94.7 - 96j
# 22                  76            94
# 23                77.2          94.9
# 24                 NaN           NaN
# 25                10.1          66.2
# 26                 NaN           NaN
# 27                68.6          82.2
# 28                80.6          88.3
# 29                  90            97
# 30                  86           NaN
# 31                 NaN           NaN
# 32          90.3 - 94k    97.5 - 98k

# %%
data_phone_laws = pd.read_excel(file,sheet_name=5)
data_phone_laws = data_phone_laws[data_phone_laws["Country / Area"].isin(europe)].reset_index(drop=True)
data_phone_laws = data_phone_laws.replace("Yesa", "Yes")
# data_seatbelt_law = data_seatbelt_law.replace("–", np.nan)
# data_seatbelt_law = data_seatbelt_law.replace("—", np.nan)
data_phone_laws.to_csv('csv/data_phone_laws.csv')
data_phone_laws
# Out:
#     Country / Area phone law Applies to hand- held phone use
# 0          Albania       Yes                             Yes  \
# 1          Austria       Yes                             Yes
# 2          Belarus       Yes                             Yes
# 3          Belgium       Yes                             Yes
# 4         Bulgaria       Yes                             Yes
# 5          Croatia       Yes                             Yes
# 6          Czechia       Yes                             Yes
# 7          Denmark       Yes                             Yes
# 8          Estonia       Yes                             Yes
# 9          Finland       Yes                             Yes
# 10          France       Yes                             Yes
# 11         Germany       Yes                             Yes
# 12          Greece       Yes                             Yes
# 13         Hungary       Yes                             Yes
# 14         Ireland       Yes                             Yes
# 15           Italy       Yes                             Yes
# 16          Latvia       Yes                             Yes
# 17       Lithuania       Yes                             Yes
# 18      Luxembourg       Yes                             Yes
# 19      Montenegro       Yes                             Yes
# 20     Netherlands       Yes                             Yes
# 21          Norway       Yes                             Yes
# 22          Poland       Yes                             Yes
# 23        Portugal       Yes                             Yes
# 24         Romania       Yes                             Yes
# 25          Serbia       Yes                             Yes
# 26        Slovakia       Yes                             Yes
# 27        Slovenia       Yes                             Yes
# 28           Spain       Yes                             Yes
# 29          Sweden       Yes                              No
# 30     Switzerland       Yes                             Yes
# 31         Ukraine       Yes                             Yes
# 32  United Kingdom       Yes                             Yes
#
#    Applies to hands- free phone use of mobile phone while driving
# 0                                No                           Yes
# 1                                No                           Yes
# 2                                No                           Yes
# 3                                No                           Yes
# 4                                No                            No
# 5                                No                           Yes
# 6                                No                           Yes
# 7                                No                            No
# 8                                No                           Yes
# 9                                No                           Yes
# 10                               No                           Yes
# 11                               No                           Yes
# 12                               No                           Yes
# 13                               No                           Yes
# 14                               No                           Yes
# 15                               No                           Yes
# 16                               No                            No
# 17                               No                           Yes
# 18                               No                            No
# 19                              Yes                           Yes
# 20                               No                           Yes
# 21                               No                            No
# 22                               No                           Yes
# 23                               No                            No
# 24                               No                            No
# 25                               No                           Yes
# 26                               No                           Yes
# 27                               No                            No
# 28                               No                           Yes
# 29                               No                            No
# 30                               No                           Yes
# 31                               No                            No
# 32                               No                           Yes

# %%
data_mobility = pd.read_excel(file,sheet_name=6)
data_mobility = data_mobility[data_mobility["Country / Area"].isin(europe)].reset_index(drop=True)
#data_mobility = data_mobility.replace("Yesa", "Yes")
# data_seatbelt_law = data_seatbelt_law.replace("–", np.nan)
# data_seatbelt_law = data_seatbelt_law.replace("—", np.nan)
data_mobility.to_csv('csv/data_mobility.csv')
data_mobility
# Out:
#     Country / Area Number of registered vehicles
# 0          Albania                       563 106  \
# 1          Austria                     7 421 647
# 2          Belarus                     4 192 291
# 3          Belgium                     7 330 718
# 4         Bulgaria                     4 031 748
# 5          Croatia                     1 996 056
# 6          Czechia                     7 325 789
# 7          Denmark                     3 131 673
# 8          Estonia                       865 040
# 9          Finland                     5 217 850
# 10          France                    42 363 000
# 11         Germany                    56 622 000
# 12          Greece                     9 489 299
# 13         Hungary                     4 022 798
# 14         Ireland                     2 573 961
# 15           Italy                    52 581 575
# 16          Latvia                       803 628
# 17       Lithuania                     1 391 568
# 18      Luxembourg                       466 472
# 19      Montenegro                       211 219
# 20     Netherlands                    10 757 655
# 21          Norway                     3 969 612
# 22          Poland                    27 409 106
# 23        Portugal                     6 590 094
# 24         Romania                     7 014 661
# 25          Serbia                     2 282 401
# 26        Slovakia                     2 606 412
# 27        Slovenia                     1 468 439
# 28           Spain                    32 986 384
# 29          Sweden                     6 102 914
# 30     Switzerland                     5 980 512
# 31         Ukraine                    14 433 709
# 32  United Kingdom                    38 388 214
#
#    Audits or star rating required for new road infrastructure
# 0                                                 Yes          \
# 1                                                 Yes
# 2                                                  No
# 3                                                 Yes
# 4                                             Partial
# 5                                             Partial
# 6                                             Partial
# 7                                             Partial
# 8                                             Partial
# 9                                                 Yes
# 10                                            Partial
# 11                                                Yes
# 12                                            Partial
# 13                                                Yes
# 14                                            Partial
# 15                                                Yes
# 16                                                Yes
# 17                                            Partial
# 18                                            Partial
# 19                                                Yes
# 20                                                Yes
# 21                                                Yes
# 22                                            Partial
# 23                                            Partial
# 24                                                Yes
# 25                                                 No
# 26                                            Partial
# 27                                            Partial
# 28                                                Yes
# 29                                            Partial
# 30                                            Partial
# 31                                                Yes
# 32                                                Yes
#
#    Inspections / star rating of existing roads
# 0                                           No  \
# 1                                          Yes
# 2                                          Yes
# 3                                          Yes
# 4                                           No
# 5                                          Yes
# 6                                          Yes
# 7                                          Yes
# 8                                          Yes
# 9                                          Yes
# 10                                         Yes
# 11                                         Yes
# 12                                         Yes
# 13                                         Yes
# 14                                         Yes
# 15                                         Yes
# 16                                         Yes
# 17                                         Yes
# 18                                         Yes
# 19                                         Yes
# 20                                         Yes
# 21                                         Yes
# 22                                         Yes
# 23                                         Yes
# 24                                         Yes
# 25                                          No
# 26                                         Yes
# 27                                         Yes
# 28                                         Yes
# 29                                         Yes
# 30                                         Yes
# 31                                         Yes
# 32                                         Yes
#
#    Design standards for the safety of pedestrians / cyclists
# 0                                             Partial         \
# 1                                                 Yes
# 2                                                 Yes
# 3                                                 Yes
# 4                                                 Yes
# 5                                                 Yes
# 6                                                 Yes
# 7                                                 Yes
# 8                                                 Yes
# 9                                                 Yes
# 10                                                Yes
# 11                                                Yes
# 12                                            Partial
# 13                                                Yes
# 14                                                Yes
# 15                                                Yes
# 16                                                Yes
# 17                                                Yes
# 18                                                Yes
# 19                                                Yes
# 20                                                Yes
# 21                                            Partial
# 22                                                Yes
# 23                                                Yes
# 24                                                Yes
# 25                                                Yes
# 26                                                Yes
# 27                                                Yes
# 28                                                Yes
# 29                                                Yes
# 30                                                 No
# 31                                                Yes
# 32                                                Yes
#
#    Investments to upgrade high risk locations
# 0                                         Yes  \
# 1                                         Yes
# 2                                         Yes
# 3                                         Yes
# 4                                          No
# 5                                         Yes
# 6                                          No
# 7                                         Yes
# 8                                         Yes
# 9                                         Yes
# 10                                        Yes
# 11                                        Yes
# 12                                        Yes
# 13                                         No
# 14                                        Yes
# 15                                         No
# 16                                        Yes
# 17                                        Yes
# 18                                        Yes
# 19                                        Yes
# 20                                        Yes
# 21                                        Yes
# 22                                        Yes
# 23                                         No
# 24                                         No
# 25                                        Yes
# 26                                        Yes
# 27                                        Yes
# 28                                        Yes
# 29                                        Yes
# 30                                        Yes
# 31                                         No
# 32                                        Yes
#
#    Policies & investment in urban public transport
# 0                                              Yes  \
# 1                                              Yes
# 2                                              Yes
# 3                                              Yes
# 4                                              Yes
# 5                                              Yes
# 6                                              Yes
# 7                                              Yes
# 8                                               No
# 9                                              Yes
# 10                                             Yes
# 11                                              No
# 12                                             Yes
# 13                                              No
# 14                                             Yes
# 15                                             Yes
# 16                                              No
# 17                                             Yes
# 18                                             Yes
# 19                                              No
# 20                                             Yes
# 21                                             Yes
# 22                                             Yes
# 23                                             Yes
# 24                                             Yes
# 25                                             Yes
# 26                                             Yes
# 27                                             Yes
# 28                                             Yes
# 29                                             Yes
# 30                                             Yes
# 31                                             Yes
# 32                                             Yes
#
#    Policies promoting walking and cycling
# 0                             Subnational
# 1                                     Yes
# 2                                     Yes
# 3                             Subnational
# 4                                     Yes
# 5                                     Yes
# 6                                     Yes
# 7                                     Yes
# 8                                     Yes
# 9                                     Yes
# 10                                    Yes
# 11                                     No
# 12                            Subnational
# 13                            Subnational
# 14                                    Yes
# 15                                    Yes
# 16                                     No
# 17                                    Yes
# 18                                    Yes
# 19                                    Yes
# 20                                    Yes
# 21                                    Yes
# 22                                    Yes
# 23                                    Yes
# 24                                     No
# 25                                     No
# 26                                    Yes
# 27                                    Yes
# 28                                    Yes
# 29                                    Yes
# 30                                    Yes
# 31                            Subnational
# 32                                    Yes

# %%
data_vehicle_standards = pd.read_excel(file,sheet_name=7)
data_vehicle_standards = data_vehicle_standards[data_vehicle_standards["Country / Area"].isin(europe)].reset_index(drop=True)
#data_mobility = data_mobility.replace("Yesa", "Yes")
# data_seatbelt_law = data_seatbelt_law.replace("–", np.nan)
# data_seatbelt_law = data_seatbelt_law.replace("—", np.nan)
data_vehicle_standards.to_csv('csv/data_vehicle_standards.csv')
data_vehicle_standards
# Out:
#     Country / Area Seat-belts Seat-belt anchorages Frontal impact Side impact
# 0          Albania         No                   No             No          No  \
# 1          Austria        Yes                  Yes            Yes         Yes
# 2          Belarus         No                   No             No          No
# 3          Belgium        Yes                  Yes            Yes         Yes
# 4         Bulgaria        Yes                  Yes            Yes         Yes
# 5          Croatia        Yes                  Yes            Yes         Yes
# 6          Czechia        Yes                  Yes            Yes         Yes
# 7          Denmark        Yes                  Yes            Yes         Yes
# 8          Estonia        Yes                  Yes            Yes         Yes
# 9          Finland        Yes                  Yes            Yes         Yes
# 10          France        Yes                  Yes            Yes         Yes
# 11         Germany        Yes                  Yes            Yes         Yes
# 12          Greece        Yes                  Yes            Yes         Yes
# 13         Hungary        Yes                  Yes            Yes         Yes
# 14         Ireland        Yes                  Yes            Yes         Yes
# 15           Italy        Yes                  Yes            Yes         Yes
# 16          Latvia        Yes                  Yes            Yes         Yes
# 17       Lithuania        Yes                  Yes            Yes         Yes
# 18      Luxembourg        Yes                  Yes            Yes         Yes
# 19      Montenegro         No                   No             No          No
# 20     Netherlands        Yes                  Yes            Yes         Yes
# 21          Norway        Yes                  Yes            Yes         Yes
# 22          Poland        Yes                  Yes            Yes         Yes
# 23        Portugal        Yes                  Yes            Yes         Yes
# 24         Romania        Yes                  Yes            Yes         Yes
# 25          Serbia         No                   No             No          No
# 26        Slovakia        Yes                  Yes            Yes         Yes
# 27        Slovenia        Yes                  Yes            Yes         Yes
# 28           Spain        Yes                  Yes            Yes         Yes
# 29          Sweden        Yes                  Yes            Yes         Yes
# 30     Switzerland        Yes                  Yes            Yes         Yes
# 31         Ukraine         No                   No             No          No
# 32  United Kingdom        Yes                  Yes            Yes         Yes
#
#    Electronic stability control Pedestrian protection Child seats
# 0                            No                    No          No  \
# 1                           Yes                   Yes         Yes
# 2                            No                    No          No
# 3                           Yes                   Yes         Yes
# 4                           Yes                   Yes         Yes
# 5                           Yes                   Yes         Yes
# 6                           Yes                   Yes         Yes
# 7                           Yes                   Yes         Yes
# 8                           Yes                   Yes         Yes
# 9                           Yes                   Yes         Yes
# 10                          Yes                   Yes         Yes
# 11                          Yes                   Yes         Yes
# 12                          Yes                   Yes         Yes
# 13                          Yes                   Yes         Yes
# 14                          Yes                   Yes         Yes
# 15                          Yes                   Yes         Yes
# 16                          Yes                   Yes         Yes
# 17                          Yes                   Yes         Yes
# 18                          Yes                   Yes         Yes
# 19                           No                    No          No
# 20                          Yes                   Yes         Yes
# 21                          Yes                   Yes         Yes
# 22                          Yes                   Yes         Yes
# 23                          Yes                   Yes         Yes
# 24                          Yes                   Yes         Yes
# 25                           No                    No          No
# 26                          Yes                   Yes         Yes
# 27                          Yes                   Yes         Yes
# 28                          Yes                   Yes         Yes
# 29                          Yes                   Yes         Yes
# 30                          Yes                   Yes         Yes
# 31                           No                    No          No
# 32                          Yes                   Yes         Yes
#
#    Motorcycle anti-lock bracking system
# 0                                    No
# 1                                   Yes
# 2                                    No
# 3                                   Yes
# 4                                   Yes
# 5                                   Yes
# 6                                   Yes
# 7                                   Yes
# 8                                   Yes
# 9                                   Yes
# 10                                  Yes
# 11                                  Yes
# 12                                  Yes
# 13                                  Yes
# 14                                  Yes
# 15                                  Yes
# 16                                  Yes
# 17                                  Yes
# 18                                  Yes
# 19                                   No
# 20                                  Yes
# 21                                  Yes
# 22                                  Yes
# 23                                  Yes
# 24                                  Yes
# 25                                   No
# 26                                  Yes
# 27                                  Yes
# 28                                  Yes
# 29                                  Yes
# 30                                  Yes
# 31                                   No
# 32                                  Yes
