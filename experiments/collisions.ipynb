# %%
import pandas as pd
import os
import sys
import matplotlib.pyplot as plt
import numpy as np

# %%
path = os.path.join(os.getcwd(), "..", "db", "COLLISION.csv")
collision_df = pd.read_csv(path)
# Out:
# C:\Users\thoma\AppData\Local\Temp\ipykernel_33332\1586323713.py:2: DtypeWarning: Columns (12,49) have mixed types. Specify dtype option on import or set low_memory=False.
#   collision_df = pd.read_csv(path)

# %%
collision_df
# Out:
#         Unnamed: 0  DT_YEAR_COLLISION  DT_MONTH_COLLISION
# 0                0               2017                   1  \
# 1                1               2017                   1
# 2                2               2017                   1
# 3                3               2017                   1
# 4                4               2017                   1
# ...            ...                ...                 ...
# 226075      226075               2021                  12
# 226076      226076               2021                  12
# 226077      226077               2021                  12
# 226078      226078               2021                  12
# 226079      226079               2021                  12
#
#        TX_MONTH_COLLISION_NL  CD_DAY_NIGHT TX_DAY_NIGHT_NL FL_WEEKEND
# 0                    januari             2           nacht          Y  \
# 1                    januari             2           nacht          Y
# 2                    januari             2           nacht          Y
# 3                    januari             1             dag          N
# 4                    januari             1             dag          N
# ...                      ...           ...             ...        ...
# 226075              december             1             dag          N
# 226076              december             1             dag          N
# 226077              december             2           nacht          N
# 226078              december             1             dag          N
# 226079              december             1             dag          N
#
#        CD_VEHICLE_SEGMENT_A
# 0                         C  \
# 1                         C
# 2                         C
# 3                         B
# 4                         A
# ...                     ...
# 226075                   J2
# 226076                    B
# 226077                    C
# 226078                   J2
# 226079                    G
#
#                                   TX_VEHICLE_SEGMENT_A_NL
# 0                                         Compacte auto's  \
# 1                                         Compacte auto's
# 2                                         Compacte auto's
# 3                  Stadsauto's / veelzijdig of subcompact
# 4                 Stadsauto's of mini-/kleine stadsauto's
# ...                                                   ...
# 226075  Pick-up, bestelwagen, bestelwagen of bedrijfsw...
# 226076             Stadsauto's / veelzijdig of subcompact
# 226077                                    Compacte auto's
# 226078  Pick-up, bestelwagen, bestelwagen of bedrijfsw...
# 226079                                        Bromfietsen
#
#         CD_VEHICLE_SEGMENT_B  ...  TX_BUILD_UP_AREA_NL  CD_LIGHT_CONDITION
# 0                          2  ...  Binnen bebouwde kom                   3  \
# 1                          2  ...  Binnen bebouwde kom                   9
# 2                          2  ...  Binnen bebouwde kom                   9
# 3                          1  ...  Binnen bebouwde kom                   1
# 4                          1  ...  Binnen bebouwde kom                   1
# ...                      ...  ...                  ...                 ...
# 226075                     6  ...  Binnen bebouwde kom                   9
# 226076                     1  ...  Binnen bebouwde kom                   1
# 226077                     2  ...  Buiten bebouwde kom                   3
# 226078                     6  ...     Niet beschikbaar                   1
# 226079                     8  ...  Buiten bebouwde kom                   1
#
#                                     TX_LIGHT_CONDITION_NL  CD_ROAD_TYPE
# 0       Nacht, openbare verlichting aanwezig en ontstoken             3  \
# 1                                                Onbekend             2
# 2                                                Onbekend             2
# 3                                                     Dag             3
# 4                                                     Dag             3
# ...                                                   ...           ...
# 226075                                           Onbekend             3
# 226076                                                Dag             3
# 226077  Nacht, openbare verlichting aanwezig en ontstoken             3
# 226078                                                Dag             2
# 226079                                                Dag             2
#
#        TX_ROAD_TYPE_NL  CD_ACCIDENT_CLASS TX_ACCIDENT_CLASS_NL
# 0          gemeenteweg                  3    met lichtgewonden  \
# 1            gewestweg                  3    met lichtgewonden
# 2            gewestweg                  3    met lichtgewonden
# 3          gemeenteweg                  3    met lichtgewonden
# 4          gemeenteweg                  3    met lichtgewonden
# ...                ...                ...                  ...
# 226075     gemeenteweg                  2    met zwaargewonden
# 226076     gemeenteweg                  3    met lichtgewonden
# 226077     gemeenteweg                  3    met lichtgewonden
# 226078       gewestweg                  3    met lichtgewonden
# 226079       gewestweg                  3    met lichtgewonden
#
#         CD_COLLISION_TYPE                                TX_COLLISON_TYPE_NL
# 0                       5                                 Met een voetganger  \
# 1                       3               Tussen 2 bestuurders: Langs achteren
# 2                       3               Tussen 2 bestuurders: Langs achteren
# 3                       4  Tss. 2 best.: langs opzij (voor-/achterkant-fl...
# 4                       4  Tss. 2 best.: langs opzij (voor-/achterkant-fl...
# ...                   ...                                                ...
# 226075                  0             Geen vermelding van de type aanrijding
# 226076                  9                                 Andere of onbekend
# 226077                  0             Geen vermelding van de type aanrijding
# 226078                  0             Geen vermelding van de type aanrijding
# 226079                  0             Geen vermelding van de type aanrijding
#
#         TX_VEHICLE_CLASS_AGE_AT_COLL_YR
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# ...                                 ...
# 226075                              0-4
# 226076                            10-14
# 226077                              0-4
# 226078                              0-4
# 226079                              0-4
#
# [226080 rows x 50 columns]

# %%
collision_df.columns
# Out:
# Index(['Unnamed: 0', 'DT_YEAR_COLLISION', 'DT_MONTH_COLLISION',
#        'TX_MONTH_COLLISION_NL', 'CD_DAY_NIGHT', 'TX_DAY_NIGHT_NL',
#        'FL_WEEKEND', 'CD_VEHICLE_SEGMENT_A', 'TX_VEHICLE_SEGMENT_A_NL',
#        'CD_VEHICLE_SEGMENT_B', 'TX_VEHICLE_SEGMENT_B_NL',
#        'MS_VEHICLE_AGE_AT_COLLISION_YR', 'TX_CLASS_VEHICLE_AGE_AT_COLL_YR',
#        'CD_FUEL_TYPE', 'TX_FUEL_TYPE_NL', 'CD_CYLINDER_CLASS_A',
#        'TX_CYLINDER_CLASS_A', 'CD_CYLINDER_CLASS_B', 'TX_CYLINDER_CLASS_B',
#        'CD_OWNER_TYPE', 'TX_OWNER_TYPE_NL', 'FL_VEHICLE', 'FL_CITY_CAR',
#        'FL_COMPACT_CAR', 'FL_BERLINE', 'FL_SUV', 'FL_MONOSPACE', 'FL_PICK_UP',
#        'FL_TRUCK_BUS', 'FL_MOTO_CYCLO', 'FL_SPORT', 'FL_UKN',
#        'CD_PROV_COLLISION', 'TX_PROV_COLLISION_NL', 'TX_REGION_COLLISON_NL',
#        'CD_WEATHER', 'TX_WEATHER_NL', 'CD_ROAD_CONDITION',
#        'TX_ROAD_CONDITION_NL', 'CD_BUILD_UP_AREA', 'TX_BUILD_UP_AREA_NL',
#        'CD_LIGHT_CONDITION', 'TX_LIGHT_CONDITION_NL', 'CD_ROAD_TYPE',
#        'TX_ROAD_TYPE_NL', 'CD_ACCIDENT_CLASS', 'TX_ACCIDENT_CLASS_NL',
#        'CD_COLLISION_TYPE', 'TX_COLLISON_TYPE_NL',
#        'TX_VEHICLE_CLASS_AGE_AT_COLL_YR'],
#       dtype='object')

# %%
for col in collision_df:
    print(col, collision_df[col].unique())
# Out:
# Unnamed: 0 [     0      1      2 ... 226077 226078 226079]
# DT_YEAR_COLLISION [2017 2018 2019 2020 2021]
# DT_MONTH_COLLISION [ 1  2  3  4  5  6  7  8 11  9 10 12]
# TX_MONTH_COLLISION_NL ['januari' 'februari' 'maart' 'april' 'mei' 'juni' 'juli' 'augustus'
#  'november' 'september' 'oktober' 'december']
# CD_DAY_NIGHT [2 1]
# TX_DAY_NIGHT_NL ['nacht' 'dag']
# FL_WEEKEND ['Y' 'N']
# CD_VEHICLE_SEGMENT_A ['C' 'B' 'A' 'CL' 'J1S' 'D' 'T' 'J1XS' 'J1M' 'J2' 'E' '99' 'CM1' 'B+' 'M'
#  'F' 'S' 'B0' 'F+' 'H' 'G' 'U' 'J1L' 'J1XL' '98']
# TX_VEHICLE_SEGMENT_A_NL ["Compacte auto's" "Stadsauto's / veelzijdig of subcompact"
#  "Stadsauto's of mini-/kleine stadsauto's" 'Ludospaces' 'SUV (maat S)'
#  'Familie sedans (maat S)' 'Vrachtwagens' 'SUV (maat XS)' 'SUV (maat M)'
#  'Pick-up, bestelwagen, bestelwagen of bedrijfswagen'
#  'Sedans voor lange afstanden (maat M)' 'Onbekend' 'Compacte monovolumes'
#  'Stadsminibusjes/minispace' 'Monovolumes' 'Luxe sedans (maat L)' 'Sport'
#  'Microstadsauto' 'Prestige sedans' 'motorfietsen' 'Bromfietsen' 'Bus'
#  'SUV (maat L)' 'SUV (maat XL)']
# CD_VEHICLE_SEGMENT_B [ 2  1  5  4  3  7  6 99  9  8]
# TX_VEHICLE_SEGMENT_B_NL ["Compacte auto's" 'Stadswagens'
#  'Monovolumes (klein en groot) en ludospace' 'SUV' 'sedans'
#  'Vrachtwagens en bussen'
#  'Pick-up, bestelwagen, bestelwagen of bedrijfswagen' 'Onbekend'
#  'Sportwagens' 'Motoren en bromfietsen']
# MS_VEHICLE_AGE_AT_COLLISION_YR [ 19  14   5   8   1   3   4   9  18  15   2  11   7   6  13  10  17  12
#   16  20  24  23  29   0  21  22  32  26  30  50  37  33  25  45  43  28
#   47  46  27  31  34  44  40  36  49  38  35  52  42  39  48  60  56  54
#   41  68  53  58  57  65  69  87  61  75  93  66  55  64  51  59  63  62
#  103  67  72  76  91  81  71  70  74]
# TX_CLASS_VEHICLE_AGE_AT_COLL_YR ['15-19' '10-14' '5-9' '0-4' '+20' nan]
# CD_FUEL_TYPE [2 1 4 5 3]
# TX_FUEL_TYPE_NL ['DIESEL' 'BENZINE' 'HYBRIDE' 'ANDEREN' 'ELEKTRISCH']
# CD_CYLINDER_CLASS_A [2 1 3 0]
# TX_CYLINDER_CLASS_A ['1400<2000' '0<1400' '>= 2000' '0']
# CD_CYLINDER_CLASS_B [5 4 3 2 6 0 1]
# TX_CYLINDER_CLASS_B ['1600<2000' '1300<1600' '1100<1300' '900<1100' '>= 2000' '0' '0<900']
# CD_OWNER_TYPE [1 2 9]
# TX_OWNER_TYPE_NL ['Particulier' 'Bedrijfswagen' 'Onbekend']
# FL_VEHICLE [1]
# FL_CITY_CAR [0 1]
# FL_COMPACT_CAR [1 0]
# FL_BERLINE [0 1]
# FL_SUV [0 1]
# FL_MONOSPACE [0 1]
# FL_PICK_UP [0 1]
# FL_TRUCK_BUS [0 1]
# FL_MOTO_CYCLO [0 1]
# FL_SPORT [0 1]
# FL_UKN [0 1]
# CD_PROV_COLLISION [21000 70000 10000 40000 30000 20001 20002 50000 90000 80000 60000]
# TX_PROV_COLLISION_NL ['Brussel-Hoofdstad' 'Provincie Limburg' 'Provincie Antwerpen'
#  'Provincie Oost-Vlaanderen' 'Provincie West-Vlaanderen'
#  'Provincie Vlaams-Brabant' 'Provincie Waals-Brabant'
#  'Provincie Henegouwen' 'Provincie Namen' 'Provincie Luxemburg'
#  'Provincie Luik']
# TX_REGION_COLLISON_NL ['Brussels Hoofdstedelijk Gewest' 'Vlaams Gewest' 'Waals Gewest']
# CD_WEATHER ['1' '9' '5' '2' '6' '3' '5/6' '7' '4/5' '2/5' '4' '2/4' '2/3' '2/6' '2/7']
# TX_WEATHER_NL ['Normaal' 'Onbekend' 'Sneeuwval' 'Regenval' 'Hagelbui'
#  'Mist (zichtbaarheid minder dan 100m)' 'Sneeuwval+Hagelbui'
#  'Andere (dikke rook,...)' 'Sterke wind, rukwind+Sneeuwval'
#  'Regenval+Sneeuwval' 'Sterke wind, rukwind'
#  'Regenval+Sterke wind, rukwind'
#  'Regenval+Mist (zichtbaarheid minder dan 100m)' 'Regenval+Hagelbui'
#  'Regenval+Andere (dikke rook,...)']
# CD_ROAD_CONDITION ['1' '9' '2' '3' '1/4' '4' '2/3' '2/4' '3/4' '2/5' '5' '1/5' '3/5']
# TX_ROAD_CONDITION_NL ['Droog' 'Onbekend' 'Nat, plassen' 'Ijzel, sneeuw' 'Droog+Proper' 'Proper'
#  'Nat, plassen+Ijzel of sneeuw' 'Nat, plassen+Proper'
#  'Ijzel, sneeuw+ roper' 'Nat, plassen+Vuil (zand, grint, bladeren,...)'
#  'Vuil (zand, grint, bladeren,...)'
#  'Droog+Vuil (zand, grint, bladeren,...)'
#  'Ijzel, sneeuw+Vuil (zand, grint, bladeren,...)']
# CD_BUILD_UP_AREA [1 2 9]
# TX_BUILD_UP_AREA_NL ['Binnen bebouwde kom' 'Buiten bebouwde kom' 'Niet beschikbaar']
# CD_LIGHT_CONDITION [3 9 1 2 4 5]
# TX_LIGHT_CONDITION_NL ['Nacht, openbare verlichting aanwezig en ontstoken' 'Onbekend' 'Dag'
#  'Dageraad - schemering' 'Nacht, geen openbare verlichting aanwezig'
#  'Nacht, openb. verlicht. aanw., maar niet ontstoken']
# CD_ROAD_TYPE [3 2 1 9]
# TX_ROAD_TYPE_NL ['gemeenteweg' 'gewestweg' 'autosnelweg' 'onbekend']
# CD_ACCIDENT_CLASS [3 2 1 4]
# TX_ACCIDENT_CLASS_NL ['met lichtgewonden' 'met zwaargewonden' 'met doden'
#  'met dodelijk gewonden']
# CD_COLLISION_TYPE ['5' '3' '4' '8' '1' '7' '9' '6' '2' '0' 'A']
# TX_COLLISON_TYPE_NL ['Met een voetganger' 'Tussen 2 bestuurders: Langs achteren'
#  'Tss. 2 best.: langs opzij (voor-/achterkant-flank)'
#  'Eén bestuurder, geen hindernis (incl. val)'
#  'Kettingbotsing (3 bestuurders of meer)'
#  'Weggebruiker tegen hindernis buiten rijbaan' 'Andere of onbekend'
#  'Weggebruiker tegen hindernis op de rijbaan'
#  'Tussen 2 bestuurders: Frontale botsing'
#  'Geen vermelding van de type aanrijding'
#  'Tussen 2 bestuurders: Flank tegen flank']
# TX_VEHICLE_CLASS_AGE_AT_COLL_YR [nan '5-9' '10-14' '15-19' '0-4' '+20']
